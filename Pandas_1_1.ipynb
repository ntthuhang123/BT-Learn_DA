# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Admin\Documents\Codegym trên lớp\FoodPrice_in_Turkey.csv',encoding='ISO-8859-1')
data
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
data.rename(columns= {'Place':'Địa điểm','ProductName':'Tên SP'},inplace=True)
data.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
data['new_column'] = 'NaN'

# %%
data
# Out:
#               Địa điểm  ProductId                   Tên SP  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price new_column
# 0         5  2013   4.4920        NaN
# 1         6  2013   4.5786        NaN
# 2        11  2013   4.7865        NaN
# 3        12  2013   5.1337        NaN
# 4         1  2014   5.5099        NaN
# ...     ...   ...      ...        ...
# 7376      8  2019  47.9040        NaN
# 7377      9  2019  49.1176        NaN
# 7378     10  2019  50.8347        NaN
# 7379     11  2019  51.7985        NaN
# 7380     12  2019  51.6071        NaN
#
# [7381 rows x 9 columns]

# %%
data['Giảm giá'] = pd.Series('10%',index=data.index)
data
# Out:
#               Địa điểm  ProductId                   Tên SP  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price new_column Giảm giá
# 0         5  2013   4.4920        NaN      10%
# 1         6  2013   4.5786        NaN      10%
# 2        11  2013   4.7865        NaN      10%
# 3        12  2013   5.1337        NaN      10%
# 4         1  2014   5.5099        NaN      10%
# ...     ...   ...      ...        ...      ...
# 7376      8  2019  47.9040        NaN      10%
# 7377      9  2019  49.1176        NaN      10%
# 7378     10  2019  50.8347        NaN      10%
# 7379     11  2019  51.7985        NaN      10%
# 7380     12  2019  51.6071        NaN      10%
#
# [7381 rows x 10 columns]

# %%
data.insert(10,'giảm giá 2',pd.Series('12%',index= data.index))
data.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column Giảm giá giảm giá 2
# 0  4.4920        NaN      10%        12%
# 1  4.5786        NaN      10%        12%
# 2  4.7865        NaN      10%        12%
# 3  5.1337        NaN      10%        12%
# 4  5.5099        NaN      10%        12%

# %%
# Sử dụng phương thức append() thêm một dòng vào cuối DataFrame

data=data.append({'Địa điểm':'NA','ProductId':'RR','Tên SP':'Rice','UmId':10,'UmName':'KG','Month':6,'Year':2021,'Price':84.3785,'Giảm giá':'10%','Giảm giá 2':'12%'},ignore_index=True)
data.tail()  # Hiển thị 5 bản ghi cuối
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11696\1709142026.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append({'Địa điểm':'NA','ProductId':'RR','Tên SP':'Rice','UmId':10,'UmName':'KG','Month':6,'Year':2021,'Price':84.3785,'Giảm giá':'10%','Giảm giá 2':'12%'},ignore_index=True)
#      Địa điểm ProductId                   Tên SP  UmId UmName  Month  Year  \
# 7377    Izmir       502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378    Izmir       502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379    Izmir       502  Cocoa (powder) - Retail     5     KG     11  2019
# 7380    Izmir       502  Cocoa (powder) - Retail     5     KG     12  2019
# 7381       NA        RR                     Rice    10     KG      6  2021
#
#         Price new_column Giảm giá giảm giá 2 Giảm giá 2
# 7377  49.1176        NaN      10%        12%        NaN
# 7378  50.8347        NaN      10%        12%        NaN
# 7379  51.7985        NaN      10%        12%        NaN
# 7380  51.6071        NaN      10%        12%        NaN
# 7381  84.3785        NaN      10%        NaN        12%

# %%
del data['new_column']
data.head()
# Out:
#            Địa điểm ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average        52  Rice - Retail     5     KG      5  2013
# 1  National Average        52  Rice - Retail     5     KG      6  2013
# 2  National Average        52  Rice - Retail     5     KG     11  2013
# 3  National Average        52  Rice - Retail     5     KG     12  2013
# 4  National Average        52  Rice - Retail     5     KG      1  2014
#
#     Price Giảm giá giảm giá 2 Giảm giá 2
# 0  4.4920      10%        12%        NaN
# 1  4.5786      10%        12%        NaN
# 2  4.7865      10%        12%        NaN
# 3  5.1337      10%        12%        NaN
# 4  5.5099      10%        12%        NaN

# %%
# Xóa một cột sử dụng phương thức pop()
# Phương thức pop trả về cột đã xóa

data.pop('Giảm giá 2')
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 7377    NaN
# 7378    NaN
# 7379    NaN
# 7380    NaN
# 7381    12%
# Name: Giảm giá 2, Length: 7382, dtype: object

# %%
data
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  Month  \
# 0     National Average        52            Rice - Retail     5     KG      5
# 1     National Average        52            Rice - Retail     5     KG      6
# 2     National Average        52            Rice - Retail     5     KG     11
# 3     National Average        52            Rice - Retail     5     KG     12
# 4     National Average        52            Rice - Retail     5     KG      1
# ...                ...       ...                      ...   ...    ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG      9
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG     10
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG     11
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG     12
# 7381                NA        RR                     Rice    10     KG      6
#
#       Year    Price Giảm giá giảm giá 2
# 0     2013   4.4920      10%        12%
# 1     2013   4.5786      10%        12%
# 2     2013   4.7865      10%        12%
# 3     2013   5.1337      10%        12%
# 4     2014   5.5099      10%        12%
# ...    ...      ...      ...        ...
# 7377  2019  49.1176      10%        12%
# 7378  2019  50.8347      10%        12%
# 7379  2019  51.7985      10%        12%
# 7380  2019  51.6071      10%        12%
# 7381  2021  84.3785      10%        NaN
#
# [7382 rows x 10 columns]

# %%
data.drop('Giảm giá', axis=1, inplace=True)
data
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  Month  \
# 0     National Average        52            Rice - Retail     5     KG      5
# 1     National Average        52            Rice - Retail     5     KG      6
# 2     National Average        52            Rice - Retail     5     KG     11
# 3     National Average        52            Rice - Retail     5     KG     12
# 4     National Average        52            Rice - Retail     5     KG      1
# ...                ...       ...                      ...   ...    ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG      9
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG     10
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG     11
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG     12
# 7381                NA        RR                     Rice    10     KG      6
#
#       Year    Price giảm giá 2
# 0     2013   4.4920        12%
# 1     2013   4.5786        12%
# 2     2013   4.7865        12%
# 3     2013   5.1337        12%
# 4     2014   5.5099        12%
# ...    ...      ...        ...
# 7377  2019  49.1176        12%
# 7378  2019  50.8347        12%
# 7379  2019  51.7985        12%
# 7380  2019  51.6071        12%
# 7381  2021  84.3785        NaN
#
# [7382 rows x 9 columns]

# %%
data.drop(['Month','Year'], axis=1, inplace=True)
data
# Out:
#               Địa điểm ProductId                   Tên SP  UmId UmName  \
# 0     National Average        52            Rice - Retail     5     KG
# 1     National Average        52            Rice - Retail     5     KG
# 2     National Average        52            Rice - Retail     5     KG
# 3     National Average        52            Rice - Retail     5     KG
# 4     National Average        52            Rice - Retail     5     KG
# ...                ...       ...                      ...   ...    ...
# 7377             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir       502  Cocoa (powder) - Retail     5     KG
# 7381                NA        RR                     Rice    10     KG
#
#         Price giảm giá 2
# 0      4.4920        12%
# 1      4.5786        12%
# 2      4.7865        12%
# 3      5.1337        12%
# 4      5.5099        12%
# ...       ...        ...
# 7377  49.1176        12%
# 7378  50.8347        12%
# 7379  51.7985        12%
# 7380  51.6071        12%
# 7381  84.3785        NaN
#
# [7382 rows x 7 columns]

# %%
data.drop(1,axis=0, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 data.drop(1,axis=0, inplace=True)
#       2 data
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[1] not found in axis'

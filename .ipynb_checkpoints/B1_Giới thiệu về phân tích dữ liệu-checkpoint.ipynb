# %%
import pandas as pd

# %%
df = pd.read_csv('./subset-covid-data.csv')
df
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB

# %%
df.date.value_counts()
# Out:
# 2020-04-12    204
# 2020-01-18      1
# 2020-04-11      1
# Name: date, dtype: int64

# %%
#3.1.Liệu các quốc gia có số lượng ca mắc mới trong ngày 12-4-2020 giống nhau hay không?
clean_df = df.loc[df.date == '2020-04-12']
clean_df
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
print(f'So ca mac moi trung binh trong ngay 04-12-2020 la: {clean_df.cases.mean()}')
# Out:
# So ca mac moi trung binh trong ngay 04-12-2020 la: 376.8186274509804

# %%
print(f'Trung vi so ca mac moi trong ngay 04-12-2020 la: {clean_df.cases.median()}')
# Out:
# Trung vi so ca mac moi trong ngay 04-12-2020 la: 11.5

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(clean_df.cases, bins= 200)
plt.show()

# %% [markdown]
# - Average of new cases of 2020-12-04 are 376.82 cases
# - Median of new cases of 2020-12-04 are 11.5, it means 50% of countries have new infections <=11 and 50% of
#   countries have new infections > 12, but the average = 376 is much greater than 11.5, it demonstrates that somes
#   countries have a very large number of new infections, completely different from the rest
# - When we see this histogram, it's obviously that almost of countries( around 160/206 coutries) have news cases so small.There are some other countries where this number is much larger, especially there are some countries with the number of cases greater than 25.000

# %%
#3.2:Number of new cases,the number os death case each country
grouped = clean_df.groupby(by ='continent').agg({'deaths': sum, 'cases':sum})
grouped
# Out:
#            deaths  cases
# continent
# Africa         52    714
# America      2111  33519
# Asia          383  12979
# Europe       2966  29591
# Oceania         4     68

# %% [markdown]
# - when we see this table, it's clean that the continent with the highest number of infections is America, there are 3       continents have this number approximately which is America, Europe and Asia
# - Some continents have lowest infections which is Africa and Oceania with just 714 cases and 52 death cases and 68 cases, 4 death cases

# %%
#3.3:Top 5 countries have the highest case
top_5_countries = df.sort_values('cases', ascending= False)
top_5_countries.head(5)
# Out:
#                       country continent        date  day  month  year  cases  \
# 198  United_States_of_America   America  2020-04-12   12      4  2020  28391
# 195            United_Kingdom    Europe  2020-04-12   12      4  2020   8719
# 190                    Turkey      Asia  2020-04-12   12      4  2020   5138
# 98                      Italy    Europe  2020-04-12   12      4  2020   4694
# 177                     Spain    Europe  2020-04-11   11      4  2020   4550
#
#      deaths country_code   population
# 198    1831          USA  327167434.0
# 195     839          GBR   66488991.0
# 190      95          TUR   82319724.0
# 98      619          ITA   60431283.0
# 177     605          ESP   46723749.0

# %% [markdown]
# Top 5 countries have the highest infections is USA, UK, turkey, Italy,Spain respectively
